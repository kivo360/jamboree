# %% [markdown]
# # Inserting Data Without Duplicates
#
# Here we test inserting data without duplicates. Afterwards we'll test for missing data inside of the databases.

# %%
from jamboree import Jamboree
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

# %%
from maya import MayaDT
import maya
import copy

# %%
import random
import orjson

# %%
from typing import List, Dict, Any

# %%
jam_session = Jamboree()

# %%
start = datetime.datetime(1986, 3, 14)
end = datetime.datetime(2020, 1, 6)

# %%
apple_df = web.DataReader("AAPL", 'yahoo', start, end)
msft_df = web.DataReader("MSFT", 'yahoo', start, end)

# %%
apple_df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 1986-03-14    0.468750    0.441964    0.441964    0.466518   96213600.0
# 1986-03-17    0.464286    0.453125    0.464286    0.464286   29680000.0
# 1986-03-18    0.486607    0.462054    0.464286    0.479911   62339200.0
# 1986-03-19    0.486607    0.470982    0.479911    0.473214   47471200.0
# 1986-03-20    0.529018    0.500000    0.500000    0.504464  226032800.0
# ...                ...         ...         ...         ...          ...
# 2019-12-30  292.690002  285.220001  289.459991  291.519989   36028600.0
# 2019-12-31  293.679993  289.519989  289.929993  293.649994   25201400.0
# 2020-01-02  300.600006  295.190002  296.239990  300.350006   33870100.0
# 2020-01-03  300.579987  296.500000  297.149994  297.429993   36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988   29596800.0
#
#              Adj Close
# Date
# 1986-03-14    0.370518
# 1986-03-17    0.368745
# 1986-03-18    0.381155
# 1986-03-19    0.375836
# 1986-03-20    0.400656
# ...                ...
# 2019-12-30  291.519989
# 2019-12-31  293.649994
# 2020-01-02  300.350006
# 2020-01-03  297.429993
# 2020-01-06  299.799988
#
# [8523 rows x 6 columns]

# %%
def get_year_month_day(time:MayaDT):
    print(f"{time.day}-{time.month}-{time.year}")

# %%
def get_time_dt(df):
    indexes = df.index
    indexes = [maya.MayaDT.from_datetime(index.to_pydatetime()) for index in indexes]
    return indexes

# %%
def df_records(df):
    return df.to_dict("records")

# %%
def standardize_record(record):
    closing_record = {}
    if "Close" in record:
        closing_record['close'] = record["Close"]
    if "Open" in record:
        closing_record['open'] = record["Open"]
    if "Low" in record:
        closing_record['low'] = record["Low"]
    if "High" in record:
        closing_record['high'] = record["High"]
    if "Volume" in record:
        closing_record['volume'] = record["Volume"]
    
    return closing_record

# %%
def standardize_outputs(records:List[Dict[str, Any]]):
    if len(records) == 0:
        return []
    _records = [standardize_record(rec) for rec in records]
    return _records

# %%
def add_time(records, times):
    if len(records) == 0 or (len(records) != len(times)):
        return []
    
    _records = []
    for index, rec in enumerate(records):
        rec['time'] = times[index]._epoch
        _records.append(rec)
    return _records

# %%
def teardown(df):
    """Breaks the dataframe into a bunch of dictionaries"""
    indexes = get_time_dt(df)
    records = df_records(df)
    standardized = standardize_outputs(records)
#     print(standardized)
    with_time = add_time(standardized, indexes)
    return with_time

# %%
dt_time = teardown(apple_df)

# %%
def flip(n=0.05):
    if random.uniform(0, 1) < n:
        return True
    return False

# %%
def create_duplicates(frame_dict_list:List[Dict]):
    if len(frame_dict_list) == 0:
        return []
    
    final_list = []
    for item in frame_dict_list:
        final_list.append(item)
        if flip(0.1):
            final_list.append(item)
    return final_list

# %%
# len(dups)

# %%
last_200 = dt_time[-200:]
last_300 = dt_time[-300:]
last_200_dups = create_duplicates(last_200)
last_300_dups = create_duplicates(last_300)

# %%
upsert_data_one = jam_session.bulk_upsert_redis({"type": "sample_save", "asset": "AAPL", "label": "duplication"}, last_200)
upsert_data_two = jam_session.bulk_upsert_redis({"type": "sample_save", "asset": "AAPL", "label": "duplication"}, last_300)
upsert_data_one_dups = jam_session.bulk_upsert_redis({"type": "sample_save", "asset": "AAPL", "label": "duplication"}, last_200_dups)
upsert_data_two_dups = jam_session.bulk_upsert_redis({"type": "sample_save", "asset": "AAPL", "label": "duplication"}, last_300_dups)
# Out:
# 2020-01-07 15:42:01.437 | INFO     | jamboree.base.main:_bulk_upsert_redis:261 - Default retcon redis
# 2020-01-07 15:42:01.439 | INFO     | jamboree.base.main:_bulk_upsert_redis:261 - Default retcon redis
# 2020-01-07 15:42:01.442 | INFO     | jamboree.base.main:_bulk_upsert_redis:261 - Default retcon redis
# 2020-01-07 15:42:01.444 | INFO     | jamboree.base.main:_bulk_upsert_redis:261 - Default retcon redis

# %%
main_hash = upsert_data_one.get("hash")

# %%
up1 = upsert_data_one.get('updated', [])
up2 = upsert_data_two.get('updated', [])
up3 = upsert_data_one_dups.get('updated', [])
up4 = upsert_data_two_dups.get('updated', [])

# %%
cr1 = [orjson.dumps(x) for x in up1]
cr2 = [orjson.dumps(x) for x in up2]
cr3 = [orjson.dumps(x) for x in up3]
cr4 = [orjson.dumps(x) for x in up4]

# %%
set1 = set(cr1)
set2 = set(cr2)
set3 = set(cr3)
set4 = set(cr4)

# %%
print(len(set1))
print(len(set2))
print(len(set3))
print(len(set4))
# Out:
# 200
# 300
# 200
# 300

# %%
jam_session.redis.sadd(set_key, *set(cr3))
# Out:
# 0

# %%
def deserialize_list(serialized_list:list):
    if len(serialized_list) == 0:
        return []
    
    return [orjson.loads(x) for x in serialized_list]

# %%
def add_timestamp(item):
    item['timestamp'] = maya.now()._epoch
    return item

# %%
def get_addable_items(set_key, added_set):
    existing = set(jam_session.redis.smembers(set_key))
    addable_items = set(set2 - existing)
    if len(addable_items) == 0:
        return []
    listified = list(addable_items)
    deku = deserialize_list(listified)
    timestamped = [add_timestamp(x) for x in deku]
    return timestamped

# %%
# updated_set = set(serialized_updated)

# %%
get_addable_items(set_key, set2)
# Out:
# [{'close': 222.22000122070312,
#   'open': 219.0500030517578,
#   'low': 216.80999755859375,
#   'high': 222.36000061035156,
#   'volume': 58323200.0,
#   'time': 1541030400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985621},
#  {'close': 208.49000549316406,
#   'open': 209.97999572753906,
#   'low': 206.75,
#   'high': 210.1199951171875,
#   'volume': 25362600.0,
#   'time': 1541635200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856315},
#  {'close': 171.25,
#   'open': 167.41000366210938,
#   'low': 167.27999877929688,
#   'high': 171.66000366210938,
#   'volume': 31495500.0,
#   'time': 1549238400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856355},
#  {'close': 181.7100067138672,
#   'open': 182.25,
#   'low': 180.9199981689453,
#   'high': 183.3000030517578,
#   'volume': 31032500.0,
#   'time': 1552435200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856384},
#  {'close': 152.2899932861328,
#   'open': 152.8800048828125,
#   'low': 151.50999450683594,
#   'high': 153.6999969482422,
#   'volume': 27023200.0,
#   'time': 1547164800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856412},
#  {'close': 212.24000549316406,
#   'open': 219.19000244140625,
#   'low': 206.08999633789062,
#   'high': 219.69000244140625,
#   'volume': 45935500.0,
#   'time': 1540771200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856446},
#  {'close': 193.52999877929688,
#   'open': 190.5,
#   'low': 189.4600067138672,
#   'high': 194.97000122070312,
#   'volume': 36928300.0,
#   'time': 1542326400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856474},
#  {'close': 156.14999389648438,
#   'open': 155.83999633789062,
#   'low': 150.07000732421875,
#   'high': 156.77000427246094,
#   'volume': 53117100.0,
#   'time': 1545868800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856505},
#  {'close': 156.22999572753906,
#   'open': 157.5,
#   'low': 154.5500030517578,
#   'high': 158.52000427246094,
#   'volume': 42291400.0,
#   'time': 1545955200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856534},
#  {'close': 156.8300018310547,
#   'open': 160.39999389648438,
#   'low': 155.3000030517578,
#   'high': 162.11000061035156,
#   'volume': 64773000.0,
#   'time': 1545264000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856565},
#  {'close': 218.86000061035156,
#   'open': 216.8800048828125,
#   'low': 216.6199951171875,
#   'high': 220.4499969482422,
#   'volume': 38358900.0,
#   'time': 1540944000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856596},
#  {'close': 178.89999389648438,
#   'open': 175.49000549316406,
#   'low': 175.35000610351562,
#   'high': 179.1199951171875,
#   'volume': 32011000.0,
#   'time': 1552262400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856625},
#  {'close': 172.91000366210938,
#   'open': 170.32000732421875,
#   'low': 169.5,
#   'high': 173.07000732421875,
#   'volume': 23999400.0,
#   'time': 1552003200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856656},
#  {'close': 170.92999267578125,
#   'open': 169.7100067138672,
#   'low': 169.49000549316406,
#   'high': 171.44000244140625,
#   'volume': 18972800.0,
#   'time': 1550534400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856687},
#  {'close': 180.91000366210938,
#   'open': 180.0,
#   'low': 179.3699951171875,
#   'high': 182.6699981689453,
#   'volume': 32467600.0,
#   'time': 1552348800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856715},
#  {'close': 165.47999572753906,
#   'open': 169.0,
#   'low': 165.27999877929688,
#   'high': 169.0800018310547,
#   'volume': 40703700.0,
#   'time': 1544745600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856741},
#  {'close': 176.97999572753906,
#   'open': 178.3699951171875,
#   'low': 175.50999450683594,
#   'high': 181.47000122070312,
#   'volume': 67825200.0,
#   'time': 1542672000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856765},
#  {'close': 170.8000030517578,
#   'open': 169.7100067138672,
#   'low': 169.3800048828125,
#   'high': 171.25999450683594,
#   'volume': 21835700.0,
#   'time': 1550102400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856796},
#  {'close': 174.24000549316406,
#   'open': 171.50999450683594,
#   'low': 170.8800048828125,
#   'high': 174.77000427246094,
#   'volume': 41387400.0,
#   'time': 1543276800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856825},
#  {'close': 155.86000061035156,
#   'open': 154.1999969482422,
#   'low': 153.25999450683594,
#   'high': 157.66000366210938,
#   'volume': 29821200.0,
#   'time': 1547683200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985685},
#  {'close': 204.47000122070312,
#   'open': 205.5500030517578,
#   'low': 202.25,
#   'high': 206.00999450683594,
#   'volume': 34365800.0,
#   'time': 1541721600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856882},
#  {'close': 172.5,
#   'open': 173.8699951171875,
#   'low': 172.02000427246094,
#   'high': 174.44000244140625,
#   'volume': 24796400.0,
#   'time': 1551916800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856913},
#  {'close': 153.07000732421875,
#   'open': 150.27000427246094,
#   'low': 150.0500030517578,
#   'high': 153.38999938964844,
#   'volume': 28710900.0,
#   'time': 1547510400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856944},
#  {'close': 180.94000244140625,
#   'open': 176.72999572753906,
#   'low': 174.92999267578125,
#   'high': 181.2899932861328,
#   'volume': 46062500.0,
#   'time': 1543363200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9856975},
#  {'close': 160.88999938964844,
#   'open': 166.0,
#   'low': 159.08999633789062,
#   'high': 167.4499969482422,
#   'volume': 49047300.0,
#   'time': 1545177600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857006},
#  {'close': 150.72999572753906,
#   'open': 156.86000061035156,
#   'low': 149.6300048828125,
#   'high': 158.16000366210938,
#   'volume': 95744600.0,
#   'time': 1545350400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857035},
#  {'close': 185.86000061035156,
#   'open': 190.0,
#   'low': 184.99000549316406,
#   'high': 190.6999969482422,
#   'volume': 41925300.0,
#   'time': 1542585600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985707},
#  {'close': 174.22999572753906,
#   'open': 174.16000366210938,
#   'low': 173.9499969482422,
#   'high': 175.8699951171875,
#   'volume': 21873400.0,
#   'time': 1551052800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857101},
#  {'close': 157.75999450683594,
#   'open': 155.47999572753906,
#   'low': 154.32000732421875,
#   'high': 158.1300048828125,
#   'volume': 33535500.0,
#   'time': 1548374400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985713},
#  {'close': 171.05999755859375,
#   'open': 171.8000030517578,
#   'low': 170.3000030517578,
#   'high': 172.3699951171875,
#   'volume': 17249700.0,
#   'time': 1550707200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857159},
#  {'close': 157.74000549316406,
#   'open': 158.52999877929688,
#   'low': 156.47999572753906,
#   'high': 159.36000061035156,
#   'volume': 35003500.0,
#   'time': 1546214400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857187},
#  {'close': 174.3300018310547,
#   'open': 173.7100067138672,
#   'low': 173.1699981689453,
#   'high': 175.3000030517578,
#   'volume': 17070200.0,
#   'time': 1551139200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857216},
#  {'close': 170.88999938964844,
#   'open': 170.10000610351562,
#   'low': 169.6999969482422,
#   'high': 171.0,
#   'volume': 22283500.0,
#   'time': 1549929600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857247},
#  {'close': 169.42999267578125,
#   'open': 171.0500030517578,
#   'low': 169.25,
#   'high': 171.2100067138672,
#   'volume': 20993400.0,
#   'time': 1549843200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857275},
#  {'close': 201.58999633789062,
#   'open': 204.3000030517578,
#   'low': 198.1699981689453,
#   'high': 204.38999938964844,
#   'volume': 66163700.0,
#   'time': 1541376000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857304},
#  {'close': 169.60000610351562,
#   'open': 165.0,
#   'low': 163.3300018310547,
#   'high': 170.08999633789062,
#   'volume': 62026000.0,
#   'time': 1544400000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857333},
#  {'close': 168.6300048828125,
#   'open': 171.66000366210938,
#   'low': 167.0,
#   'high': 171.7899932861328,
#   'volume': 47281700.0,
#   'time': 1544486400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857366},
#  {'close': 157.9199981689453,
#   'open': 154.88999938964844,
#   'low': 154.22999572753906,
#   'high': 158.85000610351562,
#   'volume': 37039700.0,
#   'time': 1546387200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857397},
#  {'close': 150.0,
#   'open': 150.85000610351562,
#   'low': 149.22000122070312,
#   'high': 151.27000427246094,
#   'volume': 32439200.0,
#   'time': 1547424000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985743},
#  {'close': 186.8000030517578,
#   'open': 193.89999389648438,
#   'low': 185.92999267578125,
#   'high': 194.47999572753906,
#   'volume': 60801000.0,
#   'time': 1542153600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985746},
#  {'close': 168.49000549316406,
#   'open': 173.49000549316406,
#   'low': 168.3000030517578,
#   'high': 174.49000549316406,
#   'volume': 42281600.0,
#   'time': 1544140800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985749},
#  {'close': 219.8000030517578,
#   'open': 217.7100067138672,
#   'low': 216.75,
#   'high': 221.3800048828125,
#   'volume': 29855800.0,
#   'time': 1540425600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857519},
#  {'close': 184.82000732421875,
#   'open': 184.4600067138672,
#   'low': 181.2100067138672,
#   'high': 184.94000244140625,
#   'volume': 40802500.0,
#   'time': 1543795200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857547},
#  {'close': 146.8300018310547,
#   'open': 148.14999389648438,
#   'low': 146.58999633789062,
#   'high': 151.5500030517578,
#   'volume': 37169200.0,
#   'time': 1545609600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985757},
#  {'close': 174.6199951171875,
#   'open': 174.24000549316406,
#   'low': 170.25999450683594,
#   'high': 174.9499969482422,
#   'volume': 44998500.0,
#   'time': 1543190400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857597},
#  {'close': 156.3000030517578,
#   'open': 155.7899932861328,
#   'low': 153.66000366210938,
#   'high': 156.3300018310547,
#   'volume': 26192100.0,
#   'time': 1548633600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857626},
#  {'close': 170.41000366210938,
#   'open': 168.99000549316406,
#   'low': 168.4199981689453,
#   'high': 170.66000366210938,
#   'volume': 23820000.0,
#   'time': 1549584000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857652},
#  {'close': 188.02000427246094,
#   'open': 185.8000030517578,
#   'low': 185.7899932861328,
#   'high': 188.38999938964844,
#   'volume': 26219800.0,
#   'time': 1552867200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985768},
#  {'close': 216.3000030517578,
#   'open': 215.89999389648438,
#   'low': 212.6699981689453,
#   'high': 220.19000244140625,
#   'volume': 47258400.0,
#   'time': 1540512000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857712},
#  {'close': 175.52999877929688,
#   'open': 175.94000244140625,
#   'low': 174.5399932861328,
#   'high': 176.0,
#   'volume': 19737400.0,
#   'time': 1551744000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985774},
#  {'close': 163.94000244140625,
#   'open': 165.4499969482422,
#   'low': 162.72999572753906,
#   'high': 168.35000610351562,
#   'volume': 44287900.0,
#   'time': 1545004800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985777},
#  {'close': 152.6999969482422,
#   'open': 154.11000061035156,
#   'low': 151.74000549316406,
#   'high': 154.47999572753906,
#   'volume': 25441500.0,
#   'time': 1548288000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857798},
#  {'close': 147.92999267578125,
#   'open': 148.6999969482422,
#   'low': 145.89999389648438,
#   'high': 148.8300018310547,
#   'volume': 54777800.0,
#   'time': 1546819200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857826},
#  {'close': 165.25,
#   'open': 163.25,
#   'low': 160.22999572753906,
#   'high': 166.14999389648438,
#   'volume': 61109800.0,
#   'time': 1548806400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857855},
#  {'close': 153.30999755859375,
#   'open': 151.2899932861328,
#   'low': 149.6300048828125,
#   'high': 154.52999877929688,
#   'volume': 45099100.0,
#   'time': 1546992000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857886},
#  {'close': 179.5500030517578,
#   'open': 182.66000366210938,
#   'low': 177.6999969482422,
#   'high': 182.8000030517578,
#   'volume': 41770000.0,
#   'time': 1543449600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857912},
#  {'close': 170.4199981689453,
#   'open': 171.25,
#   'low': 169.75,
#   'high': 171.6999969482422,
#   'volume': 24626800.0,
#   'time': 1550188800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985794},
#  {'close': 203.77000427246094,
#   'open': 201.9199981689453,
#   'low': 201.69000244140625,
#   'high': 204.72000122070312,
#   'volume': 31882900.0,
#   'time': 1541462400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9857965},
#  {'close': 170.94000244140625,
#   'open': 172.39999389648438,
#   'low': 170.33999633789062,
#   'high': 173.94000244140625,
#   'volume': 31741700.0,
#   'time': 1549497600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985799},
#  {'close': 175.85000610351562,
#   'open': 175.69000244140625,
#   'low': 173.97000122070312,
#   'high': 177.75,
#   'volume': 27436200.0,
#   'time': 1551657600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858024},
#  {'close': 172.02999877929688,
#   'open': 171.19000244140625,
#   'low': 170.99000549316406,
#   'high': 173.32000732421875,
#   'volume': 26114400.0,
#   'time': 1550620800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858053},
#  {'close': 178.5800018310547,
#   'open': 180.2899932861328,
#   'low': 177.02999877929688,
#   'high': 180.3300018310547,
#   'volume': 39531500.0,
#   'time': 1543536000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858081},
#  {'close': 176.77999877929688,
#   'open': 179.72999572753906,
#   'low': 176.5500030517578,
#   'high': 180.27000427246094,
#   'volume': 31124200.0,
#   'time': 1542758400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858112},
#  {'close': 176.69000244140625,
#   'open': 180.9499969482422,
#   'low': 176.27000427246094,
#   'high': 182.38999938964844,
#   'volume': 41344300.0,
#   'time': 1543881600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985814},
#  {'close': 186.52999877929688,
#   'open': 188.35000610351562,
#   'low': 185.9199981689453,
#   'high': 188.99000549316406,
#   'volume': 31646400.0,
#   'time': 1552953600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858165},
#  {'close': 153.9199981689453,
#   'open': 154.14999389648438,
#   'low': 151.6999969482422,
#   'high': 155.13999938964844,
#   'volume': 23130600.0,
#   'time': 1548201600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858196},
#  {'close': 172.97000122070312,
#   'open': 171.5800018310547,
#   'low': 171.3800048828125,
#   'high': 173.0,
#   'volume': 18913200.0,
#   'time': 1550793600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858224},
#  {'close': 174.52000427246094,
#   'open': 174.6699981689453,
#   'low': 173.94000244140625,
#   'high': 175.49000549316406,
#   'volume': 20810400.0,
#   'time': 1551830400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985825},
#  {'close': 186.1199951171875,
#   'open': 184.85000610351562,
#   'low': 183.74000549316406,
#   'high': 187.3300018310547,
#   'volume': 39042900.0,
#   'time': 1552608000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985828},
#  {'close': 154.94000244140625,
#   'open': 153.0800018310547,
#   'low': 153.0,
#   'high': 155.8800048828125,
#   'volume': 30569700.0,
#   'time': 1547596800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985831},
#  {'close': 142.19000244140625,
#   'open': 143.97999572753906,
#   'low': 142.0,
#   'high': 145.72000122070312,
#   'volume': 91312200.0,
#   'time': 1546473600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858336},
#  {'close': 192.22999572753906,
#   'open': 191.6300048828125,
#   'low': 191.4499969482422,
#   'high': 197.17999267578125,
#   'volume': 46882900.0,
#   'time': 1542067200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858365},
#  {'close': 148.25999450683594,
#   'open': 144.52999877929688,
#   'low': 143.8000030517578,
#   'high': 148.5500030517578,
#   'volume': 58607100.0,
#   'time': 1546560000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858396},
#  {'close': 174.17999267578125,
#   'open': 172.86000061035156,
#   'low': 172.35000610351562,
#   'high': 175.0800018310547,
#   'volume': 36101600.0,
#   'time': 1549324800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858432},
#  {'close': 183.72999572753906,
#   'open': 183.89999389648438,
#   'low': 182.55999755859375,
#   'high': 184.10000610351562,
#   'volume': 23579500.0,
#   'time': 1552521600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858463},
#  {'close': 194.1699981689453,
#   'open': 199.0,
#   'low': 193.7899932861328,
#   'high': 199.85000610351562,
#   'volume': 51135500.0,
#   'time': 1541980800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858491},
#  {'close': 153.3000030517578,
#   'open': 156.41000366210938,
#   'low': 152.6199951171875,
#   'high': 156.72999572753906,
#   'volume': 30394000.0,
#   'time': 1548115200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985852},
#  {'close': 169.10000610351562,
#   'open': 170.39999389648438,
#   'low': 169.02000427246094,
#   'high': 171.9199981689453,
#   'volume': 35627700.0,
#   'time': 1544572800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858546},
#  {'close': 154.67999267578125,
#   'open': 156.25,
#   'low': 154.11000061035156,
#   'high': 158.1300048828125,
#   'volume': 41587200.0,
#   'time': 1548720000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858575},
#  {'close': 174.8699951171875,
#   'open': 173.2100067138672,
#   'low': 172.72999572753906,
#   'high': 175.0,
#   'volume': 27835400.0,
#   'time': 1551225600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858603},
#  {'close': 150.75,
#   'open': 149.55999755859375,
#   'low': 148.52000427246094,
#   'high': 151.82000732421875,
#   'volume': 41025300.0,
#   'time': 1546905600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858632},
#  {'close': 170.17999267578125,
#   'open': 171.38999938964844,
#   'low': 169.9199981689453,
#   'high': 172.47999572753906,
#   'volume': 22490200.0,
#   'time': 1550016000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858658},
#  {'close': 166.52000427246094,
#   'open': 166.9600067138672,
#   'low': 165.92999267578125,
#   'high': 168.97999572753906,
#   'volume': 32668100.0,
#   'time': 1548979200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858685},
#  {'close': 157.1699981689453,
#   'open': 148.3000030517578,
#   'low': 146.72000122070312,
#   'high': 157.22999572753906,
#   'volume': 58582500.0,
#   'time': 1545782400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858713},
#  {'close': 207.47999572753906,
#   'open': 209.5500030517578,
#   'low': 205.42999267578125,
#   'high': 213.64999389648438,
#   'volume': 91328700.0,
#   'time': 1541116800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858742},
#  {'close': 188.16000366210938,
#   'open': 186.22999572753906,
#   'low': 184.72999572753906,
#   'high': 189.49000549316406,
#   'volume': 31035200.0,
#   'time': 1553040000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985877},
#  {'close': 172.2899932861328,
#   'open': 174.94000244140625,
#   'low': 172.10000610351562,
#   'high': 176.60000610351562,
#   'volume': 23624000.0,
#   'time': 1542931200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.98588},
#  {'close': 209.9499969482422,
#   'open': 205.97000122070312,
#   'low': 204.1300048828125,
#   'high': 210.05999755859375,
#   'volume': 33424400.0,
#   'time': 1541548800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858825},
#  {'close': 191.41000366210938,
#   'open': 188.38999938964844,
#   'low': 186.89999389648438,
#   'high': 191.97000122070312,
#   'volume': 46478800.0,
#   'time': 1542240000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858854},
#  {'close': 156.82000732421875,
#   'open': 157.5,
#   'low': 155.97999572753906,
#   'high': 157.8800048828125,
#   'volume': 33751000.0,
#   'time': 1547769600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858892},
#  {'close': 170.9499969482422,
#   'open': 170.49000549316406,
#   'low': 169.5500030517578,
#   'high': 172.57000732421875,
#   'volume': 31898600.0,
#   'time': 1544659200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858925},
#  {'close': 166.44000244140625,
#   'open': 166.11000061035156,
#   'low': 164.55999755859375,
#   'high': 169.0,
#   'volume': 40739600.0,
#   'time': 1548892800.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9858954},
#  {'close': 174.97000122070312,
#   'open': 174.27999877929688,
#   'low': 172.88999938964844,
#   'high': 175.14999389648438,
#   'volume': 25886200.0,
#   'time': 1551398400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985898},
#  {'close': 195.08999633789062,
#   'open': 190.02000427246094,
#   'low': 189.80999755859375,
#   'high': 196.3300018310547,
#   'volume': 51034200.0,
#   'time': 1553126400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9859009},
#  {'close': 174.72000122070312,
#   'open': 171.75999450683594,
#   'low': 170.4199981689453,
#   'high': 174.77999877929688,
#   'volume': 43098400.0,
#   'time': 1544054400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9859035},
#  {'close': 153.8000030517578,
#   'open': 152.5,
#   'low': 150.86000061035156,
#   'high': 153.97000122070312,
#   'volume': 35780700.0,
#   'time': 1547078400.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9859066},
#  {'close': 174.24000549316406,
#   'open': 174.64999389648438,
#   'low': 172.85000610351562,
#   'high': 175.57000732421875,
#   'volume': 28239600.0,
#   'time': 1549411200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9859095},
#  {'close': 173.14999389648438,
#   'open': 174.32000732421875,
#   'low': 172.9199981689453,
#   'high': 174.91000366210938,
#   'volume': 28215400.0,
#   'time': 1551312000.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985912},
#  {'close': 213.3000030517578,
#   'open': 211.14999389648438,
#   'low': 209.27000427246094,
#   'high': 215.17999267578125,
#   'volume': 36660000.0,
#   'time': 1540857600.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.985915},
#  {'close': 166.07000732421875,
#   'open': 165.3800048828125,
#   'low': 164.38999938964844,
#   'high': 167.52999877929688,
#   'volume': 33841500.0,
#   'time': 1545091200.0,
#   'type': 'sample_save',
#   'asset': 'AAPL',
#   'label': 'duplication',
#   'timestamp': 1578435846.9859178}]

# %%
# jam_session.redis.smembers(set_key, 0, -1)

# %%
set(retrieved - updated_set)
# Out:
# set()

# %%
len(retrieved)
# Out:
# 200

# %%
len(updated_set)
# Out:
# 200
